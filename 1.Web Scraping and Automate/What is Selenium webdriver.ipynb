# %% [markdown]
# **What is Selenium webdriver**
#
# $\;\;\;\;$ Selenium refers to a suite of tools that are widely used in the testing community when it comes to cross-browser testing. Selenium cannot automate desktop applications; it can only be used in browsers. It is considered to be one of the most preferred tool suites for automation testing of web applications as it provides support for popular web browsers which makes it very powerful.
#
# It supports a number of browsers (Google Chrome 12+, Internet Explorer 7,8,9,10, Safari 5.1+, Opera 11.5, Firefox 3+) and operating systems (Windows, Mac, Linux/Unix).
#
# Selenium also provides compatibility with different programming languages – C#, Java, JavaScript, Ruby, Python, PHP. Testers can choose which language to design test cases in, thus making Selenium highly favorable for its flexibility.
#
# **Note:** It is not mandatory to write Selenium code in the same language as the application. For example, if the application under test is written in PHP, then testers don’t have to write Selenium code in PHP. Thus, if a website is written in C#, the Selenium code can be written in PHP too.
#
# official website: https://www.selenium.dev/
#
# More info: https://www.browserstack.com/guide/selenium-webdriver-tutorial#:~:text=Selenium%20WebDriver%20is%20a%20web,language%20to%20create%20test%20scripts.

# %% [markdown]
# <br>**How to connect to a browser**
#
# ![image.png](attachment:0a946889-cf99-43ed-9201-4c4f281d0991.png)
#
# $\;\;\;\;$ How do we make sure that this package which can handle all three knows specifically how to work with the Chrome browser?
# Well, we're gonna need some sort of a bridge that bridges the Selenium code to work with the Chrome browser. And this bridge is provided by the Chrome driver. So there'll be a different driver for Safari and there'll be a different driver for Firefox. And just by switching up those drivers it'll tell Selenium how to work with the latest version of these browsers.

# %% [markdown]
# <br>**Check is connected**
#
# $\;\;\;\;$ From the code below and we conneto an example website such as amazon.com after run thecode and opena Chrome browser we can check the selenium is running that will appear the text as image below

# %%
from selenium  import webdriver

# Keep Chrome browser opern after program finishes
chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option("detach", True)

# Not frget to define options=chrome_options fo keep Chrome open
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.amazon.com")    # Open amazon website with Crome browser

driver.close() # Closed only particula tab
driver.quit() # Closed all entired the brrowser

# %% [markdown]
# ![image.png](attachment:2bafd379-11ac-48c8-97d4-52462c5182d0.png)

# %% [markdown]
# $\;\;\;\;$ **Tip:**  It's prefer actually just using quit() method  to shut down the entire browser. That way we can always start again
# from scratch and we'll have a fresh browser to work with.

# %% [markdown]
# **The differenct betwee Beautyfulsoup and Selenium**
#
# $\;\;\;\;$ In python we use Beautyfulsoup module for web scrapping and then we use selenium will can get automate bettr than normal web scrapping like a Beautifulsoup, for excample if we go to the next page beautifulsoup will scape only the current page, But Selenium will automate scraping and other thing like a human for web testing.
# - For examplesome website that we scrapping in Beautyfulsoup need to specify html headers, while with selenium will automat send our headers to website and the can get indormation frrom website. This benefit will make a less of code than Beautyfulsoup.
#
# ![image.png](attachment:d5785af3-4e02-4ad1-8a7f-89a485947c57.png)
