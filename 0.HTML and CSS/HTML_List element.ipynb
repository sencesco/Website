# %% [markdown]
# **HMTL List element**
#
# HTML lists allow web developers to group a set of related items in lists.

# %% [markdown]
# > **Unordered HTML List**
#
# An unordered list starts with the `<ul>` tag. Each list item starts with the `<li>` tag. The list items will be marked with bullets (small black circles) by default:

# %% [raw]
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>An unordered HTML list</h2>
#
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
#
# </body>
# </html>

# %% [markdown]
# The output is:
#
# ![image.png](attachment:d2908ca6-3eb2-446c-af73-52b72e8e12d9.png)

# %% [markdown]
# > **Ordered HTML List**
#
# An ordered list starts with the `<ol>` tag. Each list item starts with the `<li>` tag. The list items will be marked with numbers by default:

# %% [raw]
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>An ordered HTML list</h2>
#
# <ol>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ol>
#
# </body>
# </html>

# %% [markdown]
# The output is:
#
# ![image.png](attachment:db5868e3-693f-4fe6-b9bd-151ec4b9eeb6.png)

# %% [markdown]
# **HTML Description Lists**
#
# HTML also supports description lists. A description list is a list of terms, with a description of each term. The <dl> tag defines the description list, the `<dt>` tag defines the term (name), and the `<dd>` tag describes each term:

# %% [raw]
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>A Description List</h2>
#
# <dl>
#   <dt>Coffee</dt>
#   <dd>- black hot drink</dd>
#   <dt>Milk</dt>
#   <dd>- white cold drink</dd>
# </dl>
#
# </body>
# </html>

# %% [markdown]
# The output:
#
# ![image.png](attachment:b612522f-6311-4062-8087-bad22ff13fd9.png)
